# %% [markdown]
# ## Day- of   #30daysofPython

# %% [markdown]
# ## Topic: Files

# %% [markdown]
# * pwd
# * open a file

# %% [markdown]
# #### We can read, write & append to different files on a computer using python.
# #### The file can be text(.txt), Excel(.csv), audio & Video file etc...
# #### Even if the file doesn't exist, we can create the file in PC using python.

# %% [markdown]
# ## pwd (Present Working Directory)

# %%
pwd
# Out:
# 'C:\\Users\\MUMMIDI\\2.#30daysofpython'

# %% [markdown]
# ##### From above output 'C:\\Users\\MUMMIDI\\2.#30daysofpython' is my current directory

# %% [markdown]
# ## Opening a File

# %% [markdown]
# ![Directory.JPG](attachment:Directory.JPG)

# %% [markdown]
# ![text.JPG](attachment:text.JPG)

# %% [markdown]
# ### Above is my current directory and there is a Demo_file, a text file.
# ### The file can be opened as follows:

# %%
a = open('Demo_file.txt')   #By default reads the file even if we don't mention "r"

# %%
a = open('Demo_file.txt','r') # This also reads the file

# %% [markdown]
# ## read( )

# %%
a1 = a.read()
a1
# Out:
# 'Hi, my name is Balaji'

# %%
a1 = a.read()  #Here if we read text again it shows empty because it has already read in 1st time.
a1
# Out:
# ''

# %% [markdown]
# #### To read the line again we need to reset the index to '0' as follows

# %% [markdown]
# ## seek(0)

# %%
a.seek(0)
a.read()
# Out:
# 'Hi, my name is Balaji'

# %% [markdown]
# ###### readline( ) method reads line by line, readlines( ) method combines & reads all lines into a list.

# %% [markdown]
# ## write( )

# %%
c = open('Demo_file.txt','w') # Writes if file is empty. But if text already present it overwrites

# %% [markdown]
# ## append()

# %%
d = open('Demo_file.txt','a') # Appends text to existing text instead of overwriting.

# %% [markdown]
# ## Writing to a File

# %%
my_file = open('whoops.txt','w+')

# %%
my_file.write('This is a new line')
# Out:
# 18

# %%
my_file.seek(0)
my_file.read()
# Out:
# 'This is a new line'

# %%
my_file.close()  # always do this when you're done with a file

# %% [markdown]
# ## Appending to a File

# %%
f=open('test2.txt','a')

# %%
my_file = open('test.txt','a+')
my_file.write('\nThis is text being appended to test.txt')
my_file.write('\nAnd another line here.')
# Out:
# 23

# %%
my_file.seek(0)
print(my_file.read())
# Out:
# This is text being appended to test.txt
# And another line here.

# %%
my_file.close()

# %% [markdown]
# ### Appending with `%%writefile`

# %%
# %%writefile -a test.txt
#
# This is text being appended to test.txt
# And another line here.
# Out:
# Appending to test.txt

# %% [markdown]
# ## Iterating through a File

# %%
# %%writefile test.txt
# First Line
# Second Line
# Out:
# Overwriting test.txt

# %%
for line in open('test.txt'):
    print(line)
# Out:
# First Line
#
# Second Line

# %%
# Pertaining to the first point above
for asdf in open('test.txt'):
    print(asdf)
# Out:
# First Line
#
# Second Line
